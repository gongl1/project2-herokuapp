# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# df = pd.read_csv("./patent.tsv", sep="\t", nrows = 500 )
application_cleaned_patented = pd.read_csv("csv_output/application_cleaned_patented.csv")
# Out:
# C:\Users\gongl\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,6,7,12,13,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
application_cleaned_patented.head()
# Out:
#    Unnamed: 0  application_number filing_date application_invention_type  \
# 0           3             2045760  1948-08-23                        NaN
# 1           4             2048602         NaN                        NaN
# 2           7             2107244  1936-10-23                    Utility
# 3           8             2122612  1937-01-27                        NaN
# 4           9             2122769  1949-10-21                        NaN
#
#    examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                 NaN               NaN        NaN           NaN
# 1                 NaN               NaN        NaN           NaN
# 2  GREGORY, BERNARR E              3662        380        026000
# 3                 NaN               NaN        000        000000
# 4                 NaN               NaN        NaN           NaN
#
#   atty_docket_number                                   appl_status_desc  \
# 0                NaN  Patented File - (Old Case Added for File Track...
# 1                NaN  Patented File - (Old Case Added for File Track...
# 2                NaN                                      Patented Case
# 3                NaN  Patented File - (Old Case Added for File Track...
# 4                NaN  Patented File - (Old Case Added for File Track...
#
#   appl_status_date                file_location file_location_date  \
# 0       1986-04-25  FILE REPOSITORY (FRANCONIA)         1986-08-11
# 1       1984-03-22  FILE REPOSITORY (FRANCONIA)         2018-11-06
# 2       2000-09-20  FILE REPOSITORY (FRANCONIA)         2018-06-23
# 3       1992-10-13  FILE REPOSITORY (FRANCONIA)         1993-03-16
# 4       1987-11-04  FILE REPOSITORY (FRANCONIA)         1988-05-03
#
#   earliest_pgpub_number earliest_pgpub_date patent_number patent_issue_date  \
# 0                   NaN                 NaN       2480888        1949-09-06
# 1                   NaN                 NaN       RE19792        1935-12-17
# 2                   NaN                 NaN       6130946        2000-10-10
# 3                   NaN                 NaN       2107431        1938-02-08
# 4                   NaN                 NaN       2708722        1955-01-13
#
#          invention_title small_entity_indicator
# 0    BOX STAYING MACHINE           UNDISCOUNTED
# 1                    NaN           UNDISCOUNTED
# 2                    NaN           UNDISCOUNTED
# 3  ANTISKID CROSS CHAINS           UNDISCOUNTED
# 4                    NaN           UNDISCOUNTED

# %%
# For testing purpose, to verify steps below are correct. Do not delete this key step. 
usa_ufo_df = application_cleaned_patented.loc[application_cleaned_patented["patent_number"] == "RE45254", :]
usa_ufo_df
# Out:
#          Unnamed: 0  application_number filing_date  \
# 3150176     6857192            13907761  2013-05-31
#
#         application_invention_type examiner_full_name examiner_art_unit  \
# 3150176                   Re-Issue  POWERS, WILLIAM S              2434
#
#         uspc_class uspc_subclass atty_docket_number appl_status_desc  \
# 3150176        726        015000     19487.96.1.1.1    Patented Case
#
#         appl_status_date file_location file_location_date  \
# 3150176       2014-10-29    ELECTRONIC                NaN
#
#         earliest_pgpub_number earliest_pgpub_date patent_number  \
# 3150176                   NaN                 NaN       RE45254
#
#         patent_issue_date                              invention_title  \
# 3150176        2014-11-18  IMPLICIT POPULATION OF ACCESS CONTROL LISTS
#
#         small_entity_indicator
# 3150176           UNDISCOUNTED

# %%
patent_claims_stats_df = pd.read_csv("csv_claim_2014/patent_claims_stats.csv")
# Out:
# C:\Users\gongl\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
patent_claims_stats_df = patent_claims_stats_df.rename(columns={"pat_no": "patent_number"})
patent_claims_stats_df.tail(80)
# Out:
#          patent_number  claim_no  word_ct  char_ct  or_ct  sf_ct  cns_ct  \
# 75930584       RE45252        40      397     2670      0      0       0
# 75930585       RE45252        18      294     1851      0      0       0
# 75930586       RE45252        43       26      167      0      0       0
# 75930587       RE45252        42       33      199      0      0       0
# 75930588       RE45252        32       33      199      0      0       0
# ...                ...       ...      ...      ...    ...    ...     ...
# 75930659       RE45254        31       26      181      1      0       0
# 75930660       RE45254        30       65      408      2      0       0
# 75930661       RE45254         7       49      336      2      0       0
# 75930662       RE45254        22      201     1262      2      0       0
# 75930663       RE45254        16       41      242      0      0       0
#
#           ind_flg     appl_id
# 75930584        1  12904914.0
# 75930585        1  12904914.0
# 75930586        0  12904914.0
# 75930587        0  12904914.0
# 75930588        0  12904914.0
# ...           ...         ...
# 75930659        0  13907761.0
# 75930660        0  13907761.0
# 75930661        0  13907761.0
# 75930662        0  13907761.0
# 75930663        0  13907761.0
#
# [80 rows x 9 columns]

# %%
inner_merged_total = pd.merge(application_cleaned_patented, patent_claims_stats_df, on=["patent_number"])
inner_merged_total
# Out:
#         Unnamed: 0  application_number filing_date application_invention_type  \
# 0             4631             5010660         NaN                   Re-Issue
# 1             4631             5010660         NaN                   Re-Issue
# 2             4631             5010660         NaN                   Re-Issue
# 3             4631             5010660         NaN                   Re-Issue
# 4             4631             5010660         NaN                   Re-Issue
# ...            ...                 ...         ...                        ...
# 368339     9686450            29409384  2011-12-22                   Re-Issue
# 368340     9686456            29409392  2011-12-22                   Re-Issue
# 368341     9690661            29414353  2012-02-28                   Re-Issue
# 368342     9691451            29415275  2012-03-08                   Re-Issue
# 368343     9711716            29439750  2012-12-14                   Re-Issue
#
#            examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                         NaN              2401        220         27100
# 1                         NaN              2401        220         27100
# 2                         NaN              2401        220         27100
# 3                         NaN              2401        220         27100
# 4                         NaN              2401        220         27100
# ...                       ...               ...        ...           ...
# 368339        HYDER, PHILIP S            2917.0        D15        199000
# 368340  PALASIK, PATRICIA ANN            2915.0        D15        139000
# 368341        HYDER, PHILIP S            2917.0        D18        015000
# 368342        HYDER, PHILIP S            2917.0        D09        540000
# 368343        HYDER, PHILIP S              2917        D26        089000
#
#         atty_docket_number appl_status_desc  ...        invention_title  \
# 0                      NaN    Patented Case  ...                    NaN
# 1                      NaN    Patented Case  ...                    NaN
# 2                      NaN    Patented Case  ...                    NaN
# 3                      NaN    Patented Case  ...                    NaN
# 4                      NaN    Patented Case  ...                    NaN
# ...                    ...              ...  ...                    ...
# 368339  15491-000017/US/RE    Patented Case  ...  VACUUM TRANSFER ROBOT
# 368340  15491-000018/US/RE    Patented Case  ...  VACUUM TRANSFER ROBOT
# 368341             211,976    Patented Case  ...          PRINTER STAMP
# 368342         12375/12301    Patented Case  ...                 BOTTLE
# 368343     S1098.10004US02    Patented Case  ...                  LIGHT
#
#        small_entity_indicator claim_no word_ct char_ct or_ct sf_ct cns_ct  \
# 0                UNDISCOUNTED        4     214    1364     0     0      0
# 1                UNDISCOUNTED        2      43     250     0     0      0
# 2                UNDISCOUNTED        5      24     145     0     0      0
# 3                UNDISCOUNTED        1     268    1873     0     0      0
# 4                UNDISCOUNTED        3      46     298     0     0      0
# ...                       ...      ...     ...     ...   ...   ...    ...
# 368339           UNDISCOUNTED        1      12      74     0     0      0
# 368340           UNDISCOUNTED        1      12      74     0     0      0
# 368341                  SMALL        1      11      66     0     0      0
# 368342           UNDISCOUNTED        1      10      59     0     0      0
# 368343                  SMALL        1      10      58     0     0      0
#
#        ind_flg     appl_id
# 0            1   5010660.0
# 1            0   5010660.0
# 2            0   5010660.0
# 3            1   5010660.0
# 4            0   5010660.0
# ...        ...         ...
# 368339       1  29409384.0
# 368340       1  29409392.0
# 368341       1  29414353.0
# 368342       1  29415275.0
# 368343       1  29439750.0
#
# [368344 rows x 27 columns]

# %%
inner_merged_total.columns
# Out:
# Index(['Unnamed: 0', 'application_number', 'filing_date',
#        'application_invention_type', 'examiner_full_name', 'examiner_art_unit',
#        'uspc_class', 'uspc_subclass', 'atty_docket_number', 'appl_status_desc',
#        'appl_status_date', 'file_location', 'file_location_date',
#        'earliest_pgpub_number', 'earliest_pgpub_date', 'patent_number',
#        'patent_issue_date', 'invention_title', 'small_entity_indicator',
#        'claim_no', 'word_ct', 'char_ct', 'or_ct', 'sf_ct', 'cns_ct', 'ind_flg',
#        'appl_id'],
#       dtype='object')

# %%
inner_merged_total

patented_df = inner_merged_total.loc[inner_merged_total["appl_status_desc"] == "Patented Case", :]
patented_df = patented_df[['patent_number', 'uspc_class', 'appl_status_desc', 'claim_no', 'word_ct', 'char_ct']]
patented_df
# Out:
#        patent_number uspc_class appl_status_desc  claim_no  word_ct  char_ct
# 0            RE30349        220    Patented Case         4      214     1364
# 1            RE30349        220    Patented Case         2       43      250
# 2            RE30349        220    Patented Case         5       24      145
# 3            RE30349        220    Patented Case         1      268     1873
# 4            RE30349        220    Patented Case         3       46      298
# ...              ...        ...              ...       ...      ...      ...
# 368339       RE44567        D15    Patented Case         1       12       74
# 368340       RE43781        D15    Patented Case         1       12       74
# 368341       RE44752        D18    Patented Case         1       11       66
# 368342       RE45022        D09    Patented Case         1       10       59
# 368343       RE45162        D26    Patented Case         1       10       58
#
# [367770 rows x 6 columns]

# %%
patented_df.describe()
# Out:
#             claim_no        word_ct        char_ct
# count  367770.000000  367770.000000  367770.000000
# mean       24.957588      90.488838     577.360100
# std        37.805273     265.324922    1740.693142
# min         0.000000       0.000000       0.000000
# 25%         7.000000      23.000000     141.000000
# 50%        16.000000      36.000000     223.000000
# 75%        31.000000      76.000000     478.000000
# max      7000.000000   15148.000000   91329.000000

# %%
p = patented_df.groupby(['patent_number'])
p_index = p.count().index.tolist()
type(p_index)
p.count()['claim_no']
# Out:
# patent_number
# 8899829.0     9
# 8907138.0     7
# 8914910.0    16
# 8918269.0    10
# 8922265.0     1
#              ..
# RE45249      33
# RE45250      18
# RE45251      37
# RE45252      57
# RE45254      33
# Name: claim_no, Length: 14945, dtype: int64

# %%
p.count()
# Out:
#                uspc_class  appl_status_desc  claim_no  word_ct  char_ct
# patent_number
# 8899829.0               9                 9         9        9        9
# 8907138.0               7                 7         7        7        7
# 8914910.0              16                16        16       16       16
# 8918269.0              10                10        10       10       10
# 8922265.0               1                 1         1        1        1
# ...                   ...               ...       ...      ...      ...
# RE45249                33                33        33       33       33
# RE45250                18                18        18       18       18
# RE45251                37                37        37       37       37
# RE45252                57                57        57       57       57
# RE45254                33                33        33       33       33
#
# [14945 rows x 5 columns]

# %%
p_word_ct = p.agg({"word_ct": "sum"})
p_word_ct.tail(5)
# Out:
#                word_ct
# patent_number
# RE45249           1665
# RE45250           1138
# RE45251           2154
# RE45252           4597
# RE45254           2825

# %%
p_char_ct = p.agg({"char_ct": "sum"})
p_char_ct.tail(5)
# Out:
#                char_ct
# patent_number
# RE45249          10245
# RE45250           7417
# RE45251          13356
# RE45252          29228
# RE45254          17752

# %%
claims_summary_df = pd.DataFrame({
    "claim_no": p.count()['claim_no'],
    "total_word_ct": p_word_ct['word_ct'],
    "total_char_ct": p_char_ct['char_ct']
})

claims_summary_df['claim_no'] = claims_summary_df['claim_no'].astype('str')
claims_summary_df
# Out:
#               claim_no  total_word_ct  total_char_ct
# patent_number
# 8899829.0            9            378           2469
# 8907138.0            7            167           1102
# 8914910.0           16           1450           8901
# 8918269.0           10           1790          11805
# 8922265.0            1            850           4503
# ...                ...            ...            ...
# RE45249             33           1665          10245
# RE45250             18           1138           7417
# RE45251             37           2154          13356
# RE45252             57           4597          29228
# RE45254             33           2825          17752
#
# [14945 rows x 3 columns]

# %%
claims_summary_df.dtypes
# Out:
# claim_no         object
# total_word_ct     int64
# total_char_ct     int64
# dtype: object

# %%
claims_summary_df['claim_no'] = claims_summary_df['claim_no'].astype('int64')

# %%
# Final Dataframe I want !!! Below shows only patented cases!!! patent_number is the primary key

claims_summary_df['average_word_ct_eachclaim'] = claims_summary_df['total_word_ct'] / claims_summary_df['claim_no']
claims_summary_df['average_char_ct_eachclaim'] = claims_summary_df['total_char_ct'] / claims_summary_df['claim_no']
claims_summary_df['average_word_ct_eachclaim']= claims_summary_df['average_word_ct_eachclaim'].round(0).astype(int)
claims_summary_df['average_char_ct_eachclaim']= claims_summary_df['average_char_ct_eachclaim'].round(0).astype(int)
claims_summary_df
# Out:
#                claim_no  total_word_ct  total_char_ct  \
# patent_number
# 8899829.0             9            378           2469
# 8907138.0             7            167           1102
# 8914910.0            16           1450           8901
# 8918269.0            10           1790          11805
# 8922265.0             1            850           4503
# ...                 ...            ...            ...
# RE45249              33           1665          10245
# RE45250              18           1138           7417
# RE45251              37           2154          13356
# RE45252              57           4597          29228
# RE45254              33           2825          17752
#
#                average_word_ct_eachclaim  average_char_ct_eachclaim
# patent_number
# 8899829.0                             42                        274
# 8907138.0                             24                        157
# 8914910.0                             91                        556
# 8918269.0                            179                       1180
# 8922265.0                            850                       4503
# ...                                  ...                        ...
# RE45249                               50                        310
# RE45250                               63                        412
# RE45251                               58                        361
# RE45252                               81                        513
# RE45254                               86                        538
#
# [14945 rows x 5 columns]

# %%
claims_summary_df.dtypes
# Out:
# claim_no                     int64
# total_word_ct                int64
# total_char_ct                int64
# average_word_ct_eachclaim    int32
# average_char_ct_eachclaim    int32
# dtype: object

# %%
claims_summary_df = claims_summary_df.reset_index()
claims_summary_df
# Out:
#       patent_number  claim_no  total_word_ct  total_char_ct  \
# 0       8.89983e+06         9            378           2469
# 1       8.90714e+06         7            167           1102
# 2       8.91491e+06        16           1450           8901
# 3       8.91827e+06        10           1790          11805
# 4       8.92226e+06         1            850           4503
# ...             ...       ...            ...            ...
# 14940       RE45249        33           1665          10245
# 14941       RE45250        18           1138           7417
# 14942       RE45251        37           2154          13356
# 14943       RE45252        57           4597          29228
# 14944       RE45254        33           2825          17752
#
#        average_word_ct_eachclaim  average_char_ct_eachclaim
# 0                             42                        274
# 1                             24                        157
# 2                             91                        556
# 3                            179                       1180
# 4                            850                       4503
# ...                          ...                        ...
# 14940                         50                        310
# 14941                         63                        412
# 14942                         58                        361
# 14943                         81                        513
# 14944                         86                        538
#
# [14945 rows x 6 columns]

# %%
claims_summary_df.dtypes
# Out:
# patent_number                object
# claim_no                      int64
# total_word_ct                 int64
# total_char_ct                 int64
# average_word_ct_eachclaim     int32
# average_char_ct_eachclaim     int32
# dtype: object

# %%
from sqlalchemy import create_engine

# %%
# Create database connection!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
rds_connection_string = "postgres:useyourpassword@localhost:5432/ETL_USPTO"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['uspc_class_all',
#  'uspc_class_daysandrate',
#  'application_cleaned_all',
#  'application_cleaned_patented',
#  'all_inventors',
#  'patent_claims_stats',
#  'attorney_success_withnames',
#  'uspc_attorney_success_withnames']

# %%
# Load DataFrames into database
claims_summary_df.to_sql(name='patent_claims_stats', con=engine, if_exists='append', index=False)

# %%
# Load DataFrames into database
claims_summary_df.to_sql(name='patent_claims_stats', con=engine, if_exists='append', index=False)

# %%
claims_summary_read_df = pd.read_sql_query('select * from patent_claims_stats', con=engine)

# %%
claims_summary_read_df

# %%
claims_summary_df['average_word_ct_eachclaim'].describe()

# %%
claims_summary_df['average_char_ct_eachclaim'].describe()

# %%
claims_summary_df['claim_no'].describe()

# %%
plt.hist(claims_summary_df['claim_no'], bins=200)
plt.xlabel('claim numbers in one patented case')
plt.ylabel('counts')
plt.xlim(0,200)
plt.savefig(f"patent_claims_stats_1")
plt.show()

# %%
plt.hist(claims_summary_df['average_word_ct_eachclaim'], bins=200)
plt.xlabel('average_word_ct_eachclaim in one patented case')
plt.ylabel('counts')
plt.xlim(0,1000)
plt.savefig(f"patent_claims_stats_2")
plt.show()

# %%
plt.hist(claims_summary_df['average_char_ct_eachclaim'], bins=200)
plt.xlabel('average_char_ct_eachclaim in one patented case')
plt.ylabel('counts')
plt.xlim(0,8000)
plt.savefig(f"patent_claims_stats_3")
plt.show()

# %%
# For testing purpose, to verify steps above are correct. Do not delete this key step. 
usa_ufo_df_1 = patented_df.loc[patented_df["patent_number"] == "RE45254", :]
usa_ufo_df_1.sort_values(["claim_no"], ascending = False).head(50)

# %%
# For testing purpose, to verify steps above are correct. Do not delete this key step. 
usa_ufo_df_1.to_csv("csv_output/usa_ufo_df_1.csv")
